# %% [markdown]
# <a id='intro'></a>
# <div class="alert alert-block alert-warning">
# <h1 align="center">Introduction</h3>
# </div>

# %% [markdown]
# > To begin this project, I have to first explore the API, and extract any important information.
# <br> Fist, I will familiarize myself with the structure of the data received from each API request. </br>
# <br> Once I understand the structure of the data, I will create a function to extract the necessary information and store them in an easily accessible DataFrame. </br>
# <br> Next, I will create another function to get a chunk of data using a specified date, and store the information in a DataFrame using the previously created function from the step above. </br>
# <br> Lastly, I will collect data from various days and hours for the months of January 2018 to April 2018. </br>
#
# > Once I have collected my data, I will have to create a mapping between the character IDs and their corresponding names. Luckily, this information is given in two separate files I found through the official documentation; a json file, "gameplay.json", and an ini file, "English.ini".

# %% [markdown]
# <a id='data'></a>
# <div class="alert alert-block alert-warning">
# <h1 align="center">Data Collection</h3>
# </div>

# %% [markdown]
# <a id='data1'></a>
# ### Explore API structure
# #### Description:
# > I will send an API request and explore the structure of the returned data, and determine how to extract the data I require.
#
# #### Procedure:
# > I will first create a function to make an API request, make a request, then explore the structure of the returned data.
# 1. Build a function to get the data from an API request
# 2. Explore the data

# %%
import json
import requests
import pandas as pd
from collections import defaultdict
import time
from datetime import date, datetime, timedelta

# %% [markdown]
# ##### 1. Build a function to get the data from an API request

# %%
def get_data(url, start=None, end=None):
    '''
    Send API request for data between the start and end dates
    '''
    api_key = open("api_key.txt", "r").read()
    
    header = {
        "Authorization": api_key,
        "Accept": "application/vnd.api+json"
    }
    
    if not start and not end:
        r = requests.get(url, headers=header)
    else:
        start = str(start)[:10] + 'T' + str(start)[11:] + 'Z'
        end = str(end)[:10] + 'T' + str(end)[11:] + 'Z'
        query = {
            "sort": "createdAt",
            "filter[createdAt-start]": start,
            "filter[createdAt-end]": end
        }
        r = requests.get(url, headers=header, params=query)
    
    return r.json()

# %% [markdown]
# ##### 2. Explore the data

# %%
'''Make an API request, and store the returned data'''
url = "https://api.dc01.gamelockerapp.com/shards/global/matches"

start = datetime(2018, 4, 1, 0, 0, 0, 0)
end = start + timedelta(days=1)

data = get_data(url, start, end)

# %%
'''Explore the 'data' key'''
print(json.dumps(data['data'][0], indent=4))
# Out:
# {
#     "type": "match",
#     "id": "34F63A9E2F544B53913C0AD840572330",
#     "attributes": {
#         "createdAt": "2018-04-01T00:00:00Z",
#         "duration": 303,
#         "gameMode": "1733162751",
#         "patchVersion": "44504",
#         "shardId": "global",
#         "stats": {
#             "mapID": "319DDC57E70174B6C85EF137BAF34E9E",
#             "type": "QUICK2V2"
#         },
#         "tags": {
#             "rankingType": "UNRANKED",
#             "serverType": "QUICK2V2"
#         },
#         "titleId": "stunlock-studios-battlerite"
#     },
#     "relationships": {
#         "assets": {
#             "data": [
#                 {
#                     "type": "asset",
#                     "id": "626990a2-3541-11e8-b891-0a586460a616"
#                 }
#             ]
#         },
#         "rosters": {
#             "data": [
#                 {
#                     "type": "roster",
#                     "id": "4b490036-c870-4293-8e6f-06eb60c5ca30"
#                 },
#                 {
#                     "type": "roster",
#                     "id": "4420bdd1-8b99-4ae9-a81d-a2fec01ff9d0"
#                 }
#             ]
#         },
#         "rounds": {
#             "data": [
#                 {
#                     "type": "round",
#                     "id": "12fc083f-b82c-4eac-952b-dfbcbcd4814c"
#                 },
#                 {
#                     "type": "round",
#                     "id": "4d9ba531-84fc-4350-be0b-3d0dec7a0297"
#                 },
#                 {
#                     "type": "round",
#                     "id": "a9e1ad91-a53e-4640-8862-d601f9cf8b79"
#                 }
#             ]
#         },
#         "spectators": {
#             "data": []
#         }
#     },
#     "links": {
#         "schema": "",
#         "self": "https://api.dc01.gamelockerapp.com/shards/global/matches/34F63A9E2F544B53913C0AD840572330"
#     }
# }

# %% [markdown]
# > The 'data' key hold match data.
# <br> Each entry within 'data' includes information on the date the match was played, the match ID, the game mode played (2v2 or 3v3), and an asset ID used to access the match's telemetry data. </br>

# %%
'''Explore telemetry data'''
# Get telemetry urls
telemetry_urls = {}
for entry in data['included']:
    if entry['type'] == 'asset':
        telemetry_urls[str(entry['id'])] = entry['attributes']['URL']

# Get telemetry data
asset_id = data['data'][0]['relationships']['assets']['data'][0]['id']
url = telemetry_urls[asset_id]
r = requests.get(url, headers={"Accept":"application/vnd.api+json"})
telemetry = r.json()
print(json.dumps(telemetry, indent=4))
# Out:
# [
#     {
#         "cursor": 882384555,
#         "type": "Structures.MatchReservedUser",
#         "dataObject": {
#             "time": 1522540800310,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "serverType": "QUICK2V2",
#             "characterLevel": 15,
#             "teamId": "980201125078806528",
#             "totalTimePlayed": 278448,
#             "characterTimePlayed": 51115,
#             "character": 39373466,
#             "team": 1,
#             "rankingType": "UNRANKED",
#             "mount": 132750854,
#             "attachment": 520549809,
#             "outfit": 1471164257,
#             "emote": 553323459,
#             "league": 2,
#             "division": 4,
#             "divisionRating": 86,
#             "seasonId": 7
#         }
#     },
#     {
#         "cursor": 882956068,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 1422481252,
#             "typeId": 1860143224,
#             "sourceTypeId": 1860143224,
#             "scoreType": "USES",
#             "value": 6
#         }
#     },
#     {
#         "cursor": 882384572,
#         "type": "com.stunlock.service.matchmaking.avro.QueueEvent",
#         "dataObject": {
#             "time": 1522540799665,
#             "userId": "783238845914296320",
#             "teamId": "980201125078806528",
#             "sessionId": "8A2EF1BC9044C313DD266E1AD832473C",
#             "season": 7,
#             "eventType": "MATCH",
#             "timeJoinedQueue": "21484176547860404",
#             "timeInQueue": 30.990772,
#             "character": 39373466,
#             "characterArchetype": 4,
#             "queueTypes": [
#                 "QUICK2V2UNRANKED",
#                 "QUICK3V3UNRANKED"
#             ],
#             "limitMatchmakingRange": false,
#             "regionSamples": [
#                 {
#                     "region": "eu_north",
#                     "latencyMS": 22
#                 },
#                 {
#                     "region": "eu_west",
#                     "latencyMS": 40
#                 },
#                 {
#                     "region": "eu_east",
#                     "latencyMS": 55
#                 }
#             ],
#             "preferredRegion": "eu_north",
#             "rankingType": "UNRANKED",
#             "league": 2,
#             "division": 4,
#             "divisionRating": 86,
#             "teamSize": 1,
#             "teamMembers": [],
#             "placementGamesLeft": 0,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "matchRegion": "eu_north",
#             "teamSide": 1,
#             "autoMatchmaking": true
#         }
#     },
#     {
#         "cursor": 882914594,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541086538,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 2,
#             "character": 1422481252,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956023,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 1142987923,
#             "sourceTypeId": 1142987923,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 29
#         }
#     },
#     {
#         "cursor": 882956053,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 1422481252,
#             "typeId": 1764869728,
#             "sourceTypeId": 1764869728,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 22
#         }
#     },
#     {
#         "cursor": 882453612,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834697,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 0,
#             "character": 1422481252,
#             "serverType": "QUICK2V2",
#             "loadoutType": "DEFAULT",
#             "battleriteType": 1945460476
#         }
#     },
#     {
#         "cursor": 882956055,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 39373466,
#             "typeId": 782235039,
#             "sourceTypeId": 782235039,
#             "scoreType": "USES",
#             "value": 1
#         }
#     },
#     {
#         "cursor": 882956060,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 613085868,
#             "typeId": 478592007,
#             "sourceTypeId": 478592007,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 7
#         }
#     },
#     {
#         "cursor": 882956027,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 772061277,
#             "sourceTypeId": 772061277,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882956058,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 259914044,
#             "typeId": 1938392359,
#             "sourceTypeId": 1938392359,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 20
#         }
#     },
#     {
#         "cursor": 882453606,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 1485240119
#         }
#     },
#     {
#         "cursor": 882956043,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 39373466,
#             "typeId": 1852732415,
#             "sourceTypeId": 1852732415,
#             "scoreType": "DAMAGE_DONE",
#             "value": 36
#         }
#     },
#     {
#         "cursor": 882956009,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 1702843065,
#             "sourceTypeId": 1702843065,
#             "scoreType": "DAMAGE_DONE",
#             "value": 224
#         }
#     },
#     {
#         "cursor": 882956078,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 259914044,
#             "typeId": 1938392359,
#             "sourceTypeId": 1938392359,
#             "scoreType": "DAMAGE_DONE",
#             "value": 16
#         }
#     },
#     {
#         "cursor": 882955829,
#         "type": "Structures.MatchFinishedEvent",
#         "dataObject": {
#             "time": 1522541111614,
#             "teamOneScore": 3,
#             "teamTwoScore": 0,
#             "matchLength": 303,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "leavers": [],
#             "region": "eu_north"
#         }
#     },
#     {
#         "cursor": 882453601,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 1709776181
#         }
#     },
#     {
#         "cursor": 882479751,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540847166,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "MOUNT_DURATION",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882686378,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540957841,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 1,
#             "character": 1422481252,
#             "type": "MOUNT_DURATION",
#             "value": 11,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882593708,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540900902,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956045,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 1422481252,
#             "typeId": 1845720173,
#             "sourceTypeId": 1845720173,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 2
#         }
#     },
#     {
#         "cursor": 882878526,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541065992,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "RUNE_LASTHIT",
#             "value": 2132140508,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956456,
#         "type": "com.stunlock.battlerite.team.TeamUpdateEvent",
#         "dataObject": {
#             "time": 1522541111847,
#             "season": 7,
#             "teamID": "980197325114847232",
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userIDs": [
#                 "980189762944122880",
#                 0,
#                 0
#             ],
#             "mode": "UNRANKED",
#             "prevLeague": 2,
#             "league": 2,
#             "prevDivision": 5,
#             "division": 5,
#             "prevDivisionRating": 9,
#             "divisionRating": 39,
#             "prevWins": 4,
#             "wins": 5,
#             "prevLosses": 6,
#             "losses": 6,
#             "roundsWon": 3,
#             "roundsLost": 0,
#             "teamSize": 1,
#             "rankingChangeType": "Default",
#             "prevPlacementGamesLeft": 0,
#             "placementGamesLeft": 0,
#             "matchRegion": "eu"
#         }
#     },
#     {
#         "cursor": 882427661,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540820449,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "type": "ULTIMATE_USED",
#             "value": 478592007,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956093,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 259914044,
#             "typeId": 1720994662,
#             "sourceTypeId": 1720994662,
#             "scoreType": "USES",
#             "value": 1
#         }
#     },
#     {
#         "cursor": 882916496,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541089335,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 2,
#             "character": 613085868,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 612469406,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882453604,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 898299996
#         }
#     },
#     {
#         "cursor": 882956020,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 613085868,
#             "typeId": 1938392359,
#             "sourceTypeId": 1938392359,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 8
#         }
#     },
#     {
#         "cursor": 882956026,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 772061277,
#             "sourceTypeId": 772061277,
#             "scoreType": "DAMAGE_DONE",
#             "value": 16
#         }
#     },
#     {
#         "cursor": 882956048,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 613085868,
#             "typeId": 385747261,
#             "sourceTypeId": 385747261,
#             "scoreType": "DAMAGE_DONE",
#             "value": 15
#         }
#     },
#     {
#         "cursor": 882742321,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540990453,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 1,
#             "character": 613085868,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 612469406,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882902074,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541080019,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 2,
#             "character": 613085868,
#             "type": "HEALTH_SHARD_PICKUP",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956091,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 1422481252,
#             "typeId": 551683878,
#             "sourceTypeId": 1524552949,
#             "scoreType": "HEALING_RECEIVED",
#             "value": 24
#         }
#     },
#     {
#         "cursor": 882956094,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 259914044,
#             "typeId": 1720994662,
#             "sourceTypeId": 1720994662,
#             "scoreType": "DAMAGE_DONE",
#             "value": 31
#         }
#     },
#     {
#         "cursor": 882956075,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 613085868,
#             "typeId": 1652247682,
#             "sourceTypeId": 508323608,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 9
#         }
#     },
#     {
#         "cursor": 882956073,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 613085868,
#             "typeId": 1529787171,
#             "sourceTypeId": 1529787171,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 21
#         }
#     },
#     {
#         "cursor": 882713215,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540972543,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 1,
#             "character": 39373466,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 782235039,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882384575,
#         "type": "com.stunlock.service.matchmaking.avro.QueueEvent",
#         "dataObject": {
#             "time": 1522540799665,
#             "userId": 10066,
#             "teamId": "972483100003147776",
#             "sessionId": "75568EC2F73A496F03549773EABEA5EF",
#             "season": 7,
#             "eventType": "MATCH",
#             "timeJoinedQueue": "21484190174669910",
#             "timeInQueue": 17.363962,
#             "character": 613085868,
#             "characterArchetype": 4,
#             "queueTypes": [
#                 "QUICK2V2UNRANKED",
#                 "QUICK3V3UNRANKED"
#             ],
#             "limitMatchmakingRange": false,
#             "regionSamples": [
#                 {
#                     "region": "eu_west",
#                     "latencyMS": 43
#                 },
#                 {
#                     "region": "eu_north",
#                     "latencyMS": 55
#                 },
#                 {
#                     "region": "eu_east",
#                     "latencyMS": 56
#                 }
#             ],
#             "preferredRegion": "eu_west",
#             "rankingType": "UNRANKED",
#             "league": 2,
#             "division": 3,
#             "divisionRating": 33,
#             "teamSize": 1,
#             "teamMembers": [],
#             "placementGamesLeft": 0,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "matchRegion": "eu_north",
#             "teamSide": 2,
#             "autoMatchmaking": true
#         }
#     },
#     {
#         "cursor": 882601969,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540904484,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "HEALTH_SHARD_PICKUP",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956030,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 1422481252,
#             "typeId": 782235039,
#             "sourceTypeId": 782235039,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 6
#         }
#     },
#     {
#         "cursor": 882956033,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 613085868,
#             "typeId": 752717450,
#             "sourceTypeId": 1273702386,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 40
#         }
#     },
#     {
#         "cursor": 882384574,
#         "type": "com.stunlock.service.matchmaking.avro.QueueEvent",
#         "dataObject": {
#             "time": 1522540799665,
#             "userId": "815094029707522048",
#             "teamId": "976746467542876160",
#             "sessionId": "3C350A0BF1842F43BCEB3279F1ABE27B",
#             "season": 7,
#             "eventType": "MATCH",
#             "timeJoinedQueue": "21484175602681500",
#             "timeInQueue": 31.935951,
#             "character": 1422481252,
#             "characterArchetype": 2,
#             "queueTypes": [
#                 "QUICK2V2UNRANKED"
#             ],
#             "limitMatchmakingRange": false,
#             "regionSamples": [
#                 {
#                     "region": "eu_north",
#                     "latencyMS": 135
#                 },
#                 {
#                     "region": "poland",
#                     "latencyMS": 162
#                 },
#                 {
#                     "region": "eu_west",
#                     "latencyMS": 163
#                 }
#             ],
#             "preferredRegion": "eu_north",
#             "rankingType": "UNRANKED",
#             "league": 2,
#             "division": 5,
#             "divisionRating": 3,
#             "teamSize": 1,
#             "teamMembers": [],
#             "placementGamesLeft": 0,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "matchRegion": "eu_north",
#             "teamSide": 2,
#             "autoMatchmaking": true
#         }
#     },
#     {
#         "cursor": 882956013,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 2046833332,
#             "sourceTypeId": 375275413,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 11
#         }
#     },
#     {
#         "cursor": 882453610,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 0,
#             "character": 1422481252,
#             "serverType": "QUICK2V2",
#             "loadoutType": "DEFAULT",
#             "battleriteType": 864889084
#         }
#     },
#     {
#         "cursor": 882907476,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541083159,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 2,
#             "character": 1422481252,
#             "type": "HEALTH_SHARD_PICKUP",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956008,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 1702843065,
#             "sourceTypeId": 1702843065,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 111
#         }
#     },
#     {
#         "cursor": 882956037,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 1641118681,
#             "sourceTypeId": 99519834,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 27
#         }
#     },
#     {
#         "cursor": 882484150,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540849485,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "type": "MOUNT_DURATION",
#             "value": 14,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882738343,
#         "type": "Structures.DeathEvent",
#         "dataObject": {
#             "time": 1522540987110,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048"
#         }
#     },
#     {
#         "cursor": 882924220,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541094593,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 2,
#             "character": 259914044,
#             "type": "RUNE_LASTHIT",
#             "value": 818600880,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956016,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 363608803,
#             "sourceTypeId": 190593303,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 20
#         }
#     },
#     {
#         "cursor": 882956032,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 1773319430,
#             "sourceTypeId": 782235039,
#             "scoreType": "HEALING_RECEIVED",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882956461,
#         "type": "com.stunlock.battlerite.team.TeamUpdateEvent",
#         "dataObject": {
#             "time": 1522541111847,
#             "season": 7,
#             "teamID": "976746467542876160",
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userIDs": [
#                 "815094029707522048",
#                 0,
#                 0
#             ],
#             "mode": "UNRANKED",
#             "prevLeague": 2,
#             "league": 2,
#             "prevDivision": 5,
#             "division": 5,
#             "prevDivisionRating": 3,
#             "divisionRating": 0,
#             "prevWins": 44,
#             "wins": 44,
#             "prevLosses": 50,
#             "losses": 51,
#             "roundsWon": 0,
#             "roundsLost": 3,
#             "teamSize": 1,
#             "rankingChangeType": "Default",
#             "prevPlacementGamesLeft": 0,
#             "placementGamesLeft": 0,
#             "matchRegion": "eu"
#         }
#     },
#     {
#         "cursor": 882526882,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540870334,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "RUNE_LASTHIT",
#             "value": 205791846,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956087,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 39373466,
#             "typeId": 1353508382,
#             "sourceTypeId": 1353508382,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 3
#         }
#     },
#     {
#         "cursor": 882751658,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540998131,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 1,
#             "character": 259914044,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 573257066,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956044,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 1422481252,
#             "typeId": 1860143224,
#             "sourceTypeId": 1860143224,
#             "scoreType": "USES",
#             "value": 3
#         }
#     },
#     {
#         "cursor": 882614003,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540909336,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956041,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 1497250588,
#             "sourceTypeId": 1497250588,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 25
#         }
#     },
#     {
#         "cursor": 882956089,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 39373466,
#             "typeId": 478592007,
#             "sourceTypeId": 478592007,
#             "scoreType": "USES",
#             "value": 1
#         }
#     },
#     {
#         "cursor": 882453611,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 0,
#             "character": 1422481252,
#             "serverType": "QUICK2V2",
#             "loadoutType": "DEFAULT",
#             "battleriteType": 1864097346
#         }
#     },
#     {
#         "cursor": 882620999,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540915383,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "ULTIMATE_USED",
#             "value": 2128671887,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956012,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 812246817,
#             "sourceTypeId": 812246817,
#             "scoreType": "USES",
#             "value": 3
#         }
#     },
#     {
#         "cursor": 882956465,
#         "type": "com.stunlock.battlerite.team.TeamUpdateEvent",
#         "dataObject": {
#             "time": 1522541111847,
#             "season": 7,
#             "teamID": "972483100003147776",
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userIDs": [
#                 10066,
#                 0,
#                 0
#             ],
#             "mode": "UNRANKED",
#             "prevLeague": 2,
#             "league": 2,
#             "prevDivision": 3,
#             "division": 3,
#             "prevDivisionRating": 33,
#             "divisionRating": 4,
#             "prevWins": 155,
#             "wins": 155,
#             "prevLosses": 180,
#             "losses": 181,
#             "roundsWon": 0,
#             "roundsLost": 3,
#             "teamSize": 1,
#             "rankingChangeType": "Default",
#             "prevPlacementGamesLeft": 0,
#             "placementGamesLeft": 0,
#             "matchRegion": "eu"
#         }
#     },
#     {
#         "cursor": 882453617,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834697,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "serverType": "QUICK2V2",
#             "loadoutType": "DEFAULT",
#             "battleriteType": 1860604611
#         }
#     },
#     {
#         "cursor": 882453616,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834697,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "serverType": "QUICK2V2",
#             "loadoutType": "DEFAULT",
#             "battleriteType": 1089958696
#         }
#     },
#     {
#         "cursor": 882863421,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541060665,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 895907877,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882900754,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541079474,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 2,
#             "character": 259914044,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 573257066,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882584837,
#         "type": "Structures.DeathEvent",
#         "dataObject": {
#             "time": 1522540895682,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048"
#         }
#     },
#     {
#         "cursor": 882539748,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540876711,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 1050374556,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882916104,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541087289,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 895907877,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882626695,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540922175,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "type": "ULTIMATE_USED",
#             "value": 478592007,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956451,
#         "type": "com.stunlock.battlerite.team.TeamUpdateEvent",
#         "dataObject": {
#             "time": 1522541111847,
#             "season": 7,
#             "teamID": "980201125078806528",
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userIDs": [
#                 "783238845914296320",
#                 0,
#                 0
#             ],
#             "mode": "UNRANKED",
#             "prevLeague": 2,
#             "league": 2,
#             "prevDivision": 4,
#             "division": 3,
#             "prevDivisionRating": 86,
#             "divisionRating": 17,
#             "prevWins": 8,
#             "wins": 9,
#             "prevLosses": 2,
#             "losses": 2,
#             "roundsWon": 3,
#             "roundsLost": 0,
#             "teamSize": 1,
#             "rankingChangeType": "Default",
#             "prevPlacementGamesLeft": 0,
#             "placementGamesLeft": 0,
#             "matchRegion": "eu"
#         }
#     },
#     {
#         "cursor": 882914595,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541087016,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 2,
#             "character": 1422481252,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882912118,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541085548,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882453608,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 1088253826
#         }
#     },
#     {
#         "cursor": 882687287,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540958592,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 1,
#             "character": 39373466,
#             "type": "MOUNT_DURATION",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882722866,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540977012,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "815094029707522048",
#             "round": 1,
#             "character": 1422481252,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 1283963825,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956022,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 895907877,
#             "sourceTypeId": 895907877,
#             "scoreType": "USES",
#             "value": 2
#         }
#     },
#     {
#         "cursor": 882935302,
#         "type": "Structures.RoundFinishedEvent",
#         "dataObject": {
#             "time": 1522541100600,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "round": 2,
#             "roundLength": 66,
#             "winningTeam": 1,
#             "playerStats": [
#                 {
#                     "userID": "783238845914296320",
#                     "kills": 1,
#                     "deaths": 0,
#                     "score": 566,
#                     "damageDone": 488,
#                     "damageReceived": 104,
#                     "healingDone": 12,
#                     "healingReceived": 67,
#                     "disablesDone": 66,
#                     "disablesReceived": 7,
#                     "energyGained": 279,
#                     "energyUsed": 150,
#                     "timeAlive": 66,
#                     "abilityUses": 58
#                 },
#                 {
#                     "userID": "980189762944122880",
#                     "kills": 1,
#                     "deaths": 0,
#                     "score": 527,
#                     "damageDone": 225,
#                     "damageReceived": 287,
#                     "healingDone": 177,
#                     "healingReceived": 158,
#                     "disablesDone": 125,
#                     "disablesReceived": 72,
#                     "energyGained": 150,
#                     "energyUsed": 50,
#                     "timeAlive": 66,
#                     "abilityUses": 47
#                 },
#                 {
#                     "userID": "815094029707522048",
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 280,
#                     "damageDone": 202,
#                     "damageReceived": 315,
#                     "healingDone": 22,
#                     "healingReceived": 24,
#                     "disablesDone": 56,
#                     "disablesReceived": 134,
#                     "energyGained": 115,
#                     "energyUsed": 25,
#                     "timeAlive": 65,
#                     "abilityUses": 38
#                 },
#                 {
#                     "userID": 10066,
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 212,
#                     "damageDone": 189,
#                     "damageReceived": 260,
#                     "healingDone": 0,
#                     "healingReceived": 24,
#                     "disablesDone": 23,
#                     "disablesReceived": 57,
#                     "energyGained": 115,
#                     "energyUsed": 50,
#                     "timeAlive": 58,
#                     "abilityUses": 46
#                 }
#             ]
#         }
#     },
#     {
#         "cursor": 882912119,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541085889,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956042,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 39373466,
#             "typeId": 37,
#             "sourceTypeId": 1852732415,
#             "scoreType": "CONTROL_DONE",
#             "value": 6
#         }
#     },
#     {
#         "cursor": 882747984,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540996251,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 1,
#             "character": 613085868,
#             "type": "ENERGY_SHARD_PICKUP",
#             "value": 8,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956080,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "815094029707522048",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 1422481252,
#             "typeId": 1852732415,
#             "sourceTypeId": 1852732415,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 18
#         }
#     },
#     {
#         "cursor": 882568118,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540887907,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "type": "HEALTH_SHARD_PICKUP",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956036,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 1720994662,
#             "sourceTypeId": 1720994662,
#             "scoreType": "HEALING_RECEIVED",
#             "value": 19
#         }
#     },
#     {
#         "cursor": 882384558,
#         "type": "Structures.MatchReservedUser",
#         "dataObject": {
#             "time": 1522540800311,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "serverType": "QUICK2V2",
#             "characterLevel": 7,
#             "teamId": "972483100003147776",
#             "totalTimePlayed": 364254,
#             "characterTimePlayed": 8975,
#             "character": 613085868,
#             "team": 2,
#             "rankingType": "UNRANKED",
#             "mount": 1592946899,
#             "attachment": 725289179,
#             "outfit": 1432367486,
#             "emote": 1461132874,
#             "league": 2,
#             "division": 3,
#             "divisionRating": 33,
#             "seasonId": 7
#         }
#     },
#     {
#         "cursor": 882883027,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541069235,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 2,
#             "character": 39373466,
#             "type": "ULTIMATE_USED",
#             "value": 478592007,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882453599,
# ...
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 613085868,
#             "typeId": 131957505,
#             "sourceTypeId": 131957505,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 24
#         }
#     },
#     {
#         "cursor": 882956085,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 613085868,
#             "typeId": 1497250588,
#             "sourceTypeId": 1497250588,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 24
#         }
#     },
#     {
#         "cursor": 882956018,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 713928362,
#             "sourceTypeId": 713928362,
#             "scoreType": "CONTROL_RECEIVED",
#             "value": 3
#         }
#     },
#     {
#         "cursor": 882956076,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 39373466,
#             "typeId": 812246817,
#             "sourceTypeId": 812246817,
#             "scoreType": "HEALING_RECEIVED",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882747533,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540995367,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 1,
#             "character": 259914044,
#             "type": "RUNE_LASTHIT",
#             "value": 222924065,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882956092,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 39373466,
#             "typeId": 1773319430,
#             "sourceTypeId": 895907877,
#             "scoreType": "HEALING_DONE",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882735609,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540984074,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 1,
#             "character": 39373466,
#             "type": "ULTIMATE_USED",
#             "value": 478592007,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882753859,
#         "type": "Structures.DeathEvent",
#         "dataObject": {
#             "time": 1522541000177,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066
#         }
#     },
#     {
#         "cursor": 882453605,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "980189762944122880",
#             "round": 0,
#             "character": 259914044,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 1538513615
#         }
#     },
#     {
#         "cursor": 882956024,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 39373466,
#             "typeId": 363608803,
#             "sourceTypeId": 190593303,
#             "scoreType": "HEALING_RECEIVED",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882956088,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111617,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 2,
#             "character": 259914044,
#             "typeId": 1529787171,
#             "sourceTypeId": 1529787171,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 34
#         }
#     },
#     {
#         "cursor": 882956057,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 259914044,
#             "typeId": 359156696,
#             "sourceTypeId": 359156696,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 25
#         }
#     },
#     {
#         "cursor": 882756956,
#         "type": "Structures.RoundFinishedEvent",
#         "dataObject": {
#             "time": 1522541002807,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "round": 1,
#             "roundLength": 46,
#             "winningTeam": 1,
#             "playerStats": [
#                 {
#                     "userID": "783238845914296320",
#                     "kills": 1,
#                     "deaths": 0,
#                     "score": 503,
#                     "damageDone": 422,
#                     "damageReceived": 200,
#                     "healingDone": 36,
#                     "healingReceived": 97,
#                     "disablesDone": 45,
#                     "disablesReceived": 15,
#                     "energyGained": 249,
#                     "energyUsed": 150,
#                     "timeAlive": 46,
#                     "abilityUses": 44
#                 },
#                 {
#                     "userID": "980189762944122880",
#                     "kills": 1,
#                     "deaths": 0,
#                     "score": 342,
#                     "damageDone": 206,
#                     "damageReceived": 79,
#                     "healingDone": 76,
#                     "healingReceived": 45,
#                     "disablesDone": 60,
#                     "disablesReceived": 35,
#                     "energyGained": 115,
#                     "energyUsed": 25,
#                     "timeAlive": 46,
#                     "abilityUses": 37
#                 },
#                 {
#                     "userID": "815094029707522048",
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 136,
#                     "damageDone": 79,
#                     "damageReceived": 302,
#                     "healingDone": 18,
#                     "healingReceived": 0,
#                     "disablesDone": 39,
#                     "disablesReceived": 41,
#                     "energyGained": 87,
#                     "energyUsed": 25,
#                     "timeAlive": 33,
#                     "abilityUses": 22
#                 },
#                 {
#                     "userID": 10066,
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 265,
#                     "damageDone": 218,
#                     "damageReceived": 274,
#                     "healingDone": 36,
#                     "healingReceived": 24,
#                     "disablesDone": 11,
#                     "disablesReceived": 64,
#                     "energyGained": 135,
#                     "energyUsed": 25,
#                     "timeAlive": 45,
#                     "abilityUses": 37
#                 }
#             ]
#         }
#     },
#     {
#         "cursor": 882956040,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 613085868,
#             "typeId": 1764869728,
#             "sourceTypeId": 1764869728,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 22
#         }
#     },
#     {
#         "cursor": 882956062,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 259914044,
#             "typeId": 1427415519,
#             "sourceTypeId": 0,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 12
#         }
#     },
#     {
#         "cursor": 882956010,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111614,
#             "accountId": "980189762944122880",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 259914044,
#             "typeId": 1273702386,
#             "sourceTypeId": 1273702386,
#             "scoreType": "USES",
#             "value": 6
#         }
#     },
#     {
#         "cursor": 882956035,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 613085868,
#             "typeId": 551683878,
#             "sourceTypeId": 2118277350,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 16
#         }
#     },
#     {
#         "cursor": 882689597,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540959787,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 1,
#             "character": 613085868,
#             "type": "MOUNT_DURATION",
#             "value": 13,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882628577,
#         "type": "Structures.RoundFinishedEvent",
#         "dataObject": {
#             "time": 1522540924941,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "round": 0,
#             "roundLength": 77,
#             "winningTeam": 1,
#             "playerStats": [
#                 {
#                     "userID": "783238845914296320",
#                     "kills": 2,
#                     "deaths": 0,
#                     "score": 502,
#                     "damageDone": 428,
#                     "damageReceived": 350,
#                     "healingDone": 48,
#                     "healingReceived": 188,
#                     "disablesDone": 26,
#                     "disablesReceived": 64,
#                     "energyGained": 379,
#                     "energyUsed": 325,
#                     "timeAlive": 77,
#                     "abilityUses": 87
#                 },
#                 {
#                     "userID": "980189762944122880",
#                     "kills": 0,
#                     "deaths": 0,
#                     "score": 551,
#                     "damageDone": 254,
#                     "damageReceived": 262,
#                     "healingDone": 214,
#                     "healingReceived": 114,
#                     "disablesDone": 83,
#                     "disablesReceived": 78,
#                     "energyGained": 165,
#                     "energyUsed": 50,
#                     "timeAlive": 77,
#                     "abilityUses": 64
#                 },
#                 {
#                     "userID": "815094029707522048",
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 393,
#                     "damageDone": 329,
#                     "damageReceived": 314,
#                     "healingDone": 0,
#                     "healingReceived": 15,
#                     "disablesDone": 64,
#                     "disablesReceived": 66,
#                     "energyGained": 147,
#                     "energyUsed": 100,
#                     "timeAlive": 50,
#                     "abilityUses": 49
#                 },
#                 {
#                     "userID": 10066,
#                     "kills": 0,
#                     "deaths": 1,
#                     "score": 453,
#                     "damageDone": 343,
#                     "damageReceived": 299,
#                     "healingDone": 32,
#                     "healingReceived": 38,
#                     "disablesDone": 78,
#                     "disablesReceived": 43,
#                     "energyGained": 116,
#                     "energyUsed": 100,
#                     "timeAlive": 76,
#                     "abilityUses": 46
#                 }
#             ]
#         }
#     },
#     {
#         "cursor": 882956034,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111615,
#             "accountId": 10066,
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 0,
#             "character": 613085868,
#             "typeId": 1702843065,
#             "sourceTypeId": 1702843065,
#             "scoreType": "DAMAGE_RECEIVED",
#             "value": 64
#         }
#     },
#     {
#         "cursor": 882565261,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540886952,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "type": "ENERGY_ABILITY_USED",
#             "value": 895907877,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882453602,
#         "type": "Structures.BattleritePickEvent",
#         "dataObject": {
#             "time": 1522540834696,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": "783238845914296320",
#             "round": 0,
#             "character": 39373466,
#             "serverType": "QUICK2V2",
#             "loadoutType": "HOMEMADE",
#             "battleriteType": 1813257010
#         }
#     },
#     {
#         "cursor": 882384571,
#         "type": "Structures.MatchStart",
#         "dataObject": {
#             "time": 1522540800310,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "version": "44504",
#             "type": "QUICK2V2",
#             "gameMode": 1733162751,
#             "mapID": "319DDC57E70174B6C85EF137BAF34E9E",
#             "teamSize": 2,
#             "region": "eu_north"
#         }
#     },
#     {
#         "cursor": 882956061,
#         "type": "Structures.UserRoundSpell",
#         "dataObject": {
#             "time": 1522541111616,
#             "accountId": "783238845914296320",
#             "matchId": "34F63A9E2F544B53913C0AD840572330",
#             "round": 1,
#             "character": 39373466,
#             "typeId": 772061277,
#             "sourceTypeId": 772061277,
#             "scoreType": "ENERGY_RECEIVED",
#             "value": 6
#         }
#     },
#     {
#         "cursor": 882526883,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522540870572,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 0,
#             "character": 613085868,
#             "type": "HEALTH_SHARD_PICKUP",
#             "value": 12,
#             "timeIntoRound": 0
#         }
#     },
#     {
#         "cursor": 882818224,
#         "type": "Structures.RoundEvent",
#         "dataObject": {
#             "time": 1522541034264,
#             "matchID": "34F63A9E2F544B53913C0AD840572330",
#             "externalMatchID": "",
#             "userID": 10066,
#             "round": 2,
#             "character": 613085868,
#             "type": "MOUNT_DURATION",
#             "value": 10,
#             "timeIntoRound": 0
#         }
#     }
# ]

# %% [markdown]
# > There are two important TelemetryData types here: "Structures.MatchReservedUser", and "Structures.MatchFinishedEvent".
# <br> "Structures.MatchReservedUser" holds player information such as the character ID the that was played, the player's ranking (bronze, silver, gold, etc.), the player's team, and the match's format (ranked, or casual). </br>
# <br> "Structures.MatchFinishedEvent" holds each team's score, which will be useful in determining which players won the match. </br>

# %%
'''Explore the 'included' key'''
print(json.dumps(data['included'], indent=4))
# Out:
# [
#     {
#         "type": "participant",
#         "id": "6c7665d4-b033-4245-bd4a-c7fdec5c8569",
#         "attributes": {
#             "actor": "1208445212",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 232,
#                 "attachment": 2143958509,
#                 "damageDone": 935,
#                 "damageReceived": 938,
#                 "deaths": 3,
#                 "disablesDone": 217,
#                 "disablesReceived": 166,
#                 "emote": 914102918,
#                 "energyGained": 536,
#                 "energyUsed": 375,
#                 "healingDone": 130,
#                 "healingReceived": 232,
#                 "kills": 1,
#                 "mount": 1302058678,
#                 "outfit": 1379696215,
#                 "score": 1282,
#                 "side": 1,
#                 "timeAlive": 190
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "779814866243452928"
#                 }
#             }
#         }
#     },
#     {
#         "type": "asset",
#         "id": "a5b63ec3-3541-11e8-94d3-0a5864602bae",
#         "attributes": {
#             "URL": "https://cdn.gamelockerapp.com/stunlock-studios-battlerite/global/2018/04/01/00/14/a5b63ec3-3541-11e8-94d3-0a5864602bae-telemetry.json",
#             "createdAt": "2018-04-01T00:14:30Z",
#             "description": "",
#             "name": "telemetry"
#         }
#     },
#     {
#         "type": "round",
#         "id": "8dc07ad8-6e39-400e-8336-23992e37996e",
#         "attributes": {
#             "duration": 29,
#             "ordinal": 0,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "1528a283-2bf9-44d1-b5b0-a5801129c70f",
#         "attributes": {
#             "actor": "1496688063",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 204,
#                 "attachment": 1635067411,
#                 "damageDone": 784,
#                 "damageReceived": 1052,
#                 "deaths": 2,
#                 "disablesDone": 86,
#                 "disablesReceived": 225,
#                 "emote": 1522544256,
#                 "energyGained": 752,
#                 "energyUsed": 500,
#                 "healingDone": 539,
#                 "healingReceived": 323,
#                 "kills": 4,
#                 "mount": 1603856734,
#                 "outfit": 30138863,
#                 "score": 1411,
#                 "side": 1,
#                 "timeAlive": 291
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "973762206573436928"
#                 }
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "980230818830135296",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "44223365-b7cc-499f-aff0-1223d8dee99b",
#         "attributes": {
#             "actor": "1318732017",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 233,
#                 "attachment": 795662654,
#                 "damageDone": 1246,
#                 "damageReceived": 1144,
#                 "deaths": 3,
#                 "disablesDone": 343,
#                 "disablesReceived": 205,
#                 "emote": 1866269483,
#                 "energyGained": 764,
#                 "energyUsed": 125,
#                 "healingDone": 40,
#                 "healingReceived": 100,
#                 "kills": 2,
#                 "mount": 1393947372,
#                 "outfit": 833481106,
#                 "score": 1629,
#                 "side": 2,
#                 "timeAlive": 246
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "979488397649420288"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "3ea3dc5c-db05-4183-93ab-3cdb7ef9a59f",
#         "attributes": {
#             "actor": "613085868",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 129,
#                 "attachment": 725289179,
#                 "damageDone": 750,
#                 "damageReceived": 833,
#                 "deaths": 3,
#                 "disablesDone": 112,
#                 "disablesReceived": 164,
#                 "emote": 1461132874,
#                 "energyGained": 366,
#                 "energyUsed": 175,
#                 "healingDone": 68,
#                 "healingReceived": 86,
#                 "kills": 0,
#                 "mount": 1592946899,
#                 "outfit": 1432367486,
#                 "score": 930,
#                 "side": 2,
#                 "timeAlive": 179
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "10066"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "980226622844243968",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/980226622844243968"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "81a14cd3-55e4-42c1-85de-025b0c971f86",
#         "attributes": {
#             "actor": "842211418",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 112,
#                 "attachment": 114634374,
#                 "damageDone": 850,
#                 "damageReceived": 552,
#                 "deaths": 1,
#                 "disablesDone": 125,
#                 "disablesReceived": 155,
#                 "emote": 1110424602,
#                 "energyGained": 389,
#                 "energyUsed": 0,
#                 "healingDone": 52,
#                 "healingReceived": 199,
#                 "kills": 3,
#                 "mount": 1514111634,
#                 "outfit": 908242099,
#                 "score": 1027,
#                 "side": 2,
#                 "timeAlive": 163
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "961748057458876416"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "3921e65a-92a1-4ca0-9ecf-0d30ae090b63",
#         "attributes": {
#             "duration": 76,
#             "ordinal": 0,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "971372861484883968",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "961260605304659968",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/961260605304659968"
#         }
#     },
#     {
#         "type": "player",
#         "id": "937809125767835648",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/937809125767835648"
#         }
#     },
#     {
#         "type": "round",
#         "id": "40cc73ab-ba06-4b13-baee-447abee58766",
#         "attributes": {
#             "duration": 65,
#             "ordinal": 3,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "453e21ca-bf21-43a1-aff6-7b8e3cd9c573",
#         "attributes": {
#             "actor": "259914044",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 148,
#                 "attachment": 647026752,
#                 "damageDone": 685,
#                 "damageReceived": 628,
#                 "deaths": 0,
#                 "disablesDone": 268,
#                 "disablesReceived": 185,
#                 "emote": 1935147242,
#                 "energyGained": 430,
#                 "energyUsed": 125,
#                 "healingDone": 467,
#                 "healingReceived": 317,
#                 "kills": 2,
#                 "mount": 1302058678,
#                 "outfit": 2101526377,
#                 "score": 1420,
#                 "side": 1,
#                 "timeAlive": 189
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "980189762944122880"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "2ef80548-aabf-4735-97a0-fb78dbbb3a67",
#         "attributes": {
#             "duration": 82,
#             "ordinal": 0,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "972674854530727936",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/972674854530727936"
#         }
#     },
#     {
#         "type": "round",
#         "id": "a9e1ad91-a53e-4640-8862-d601f9cf8b79",
#         "attributes": {
#             "duration": 77,
#             "ordinal": 0,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "2240bea8-4d85-4681-a7cc-3448da138d5a",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 2,
#                 "divisionRating": 86,
#                 "league": 2,
#                 "losses": 30,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 1,
#                 "prevDivisionRating": 13,
#                 "prevLeague": 2,
#                 "prevLosses": 29,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 36,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 3,
#                 "roundsWon": 1,
#                 "score": 1,
#                 "season": 7,
#                 "teamSize": 2,
#                 "wins": 36
#             },
#             "won": "false"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "2b77165c-5f53-4bd3-98d6-6f4888ef8966"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "5bac1947-46c9-4636-96b1-d90f9b2b912e"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "978796308359950336"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "974109931747868672",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/974109931747868672"
#         }
#     },
#     {
#         "type": "roster",
#         "id": "a9058cbe-36ac-48d5-aeaf-7ff343ca98d2",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": -1,
#                 "divisionRating": -1,
#                 "league": -1,
#                 "losses": 1,
#                 "matchRegion": "south_america",
#                 "placementGamesLeft": 3,
#                 "prevDivision": -1,
#                 "prevDivisionRating": -1,
#                 "prevLeague": -1,
#                 "prevLosses": 0,
#                 "prevPlacementGamesLeft": 4,
#                 "prevWins": 1,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 3,
#                 "roundsWon": 1,
#                 "score": 1,
#                 "season": 7,
#                 "teamSize": 3,
#                 "wins": 1
#             },
#             "won": "false"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "44223365-b7cc-499f-aff0-1223d8dee99b"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "86263f36-f936-4aa8-a492-a05d9b666d70"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "2421d03e-4f41-4f15-a743-19badcf4fac3"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "980230818830135296"
#                 }
#             }
#         }
#     },
#     {
#         "type": "asset",
#         "id": "cc434b4a-3541-11e8-b6f7-0a5864608818",
#         "attributes": {
#             "URL": "https://cdn.gamelockerapp.com/stunlock-studios-battlerite/global/2018/04/01/00/15/cc434b4a-3541-11e8-b6f7-0a5864608818-telemetry.json",
#             "createdAt": "2018-04-01T00:15:35Z",
#             "description": "",
#             "name": "telemetry"
#         }
#     },
#     {
#         "type": "team",
#         "id": "972483100003147776",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "569ad578-51f3-4158-86c1-2104bb41f8c5",
#         "attributes": {
#             "duration": 66,
#             "ordinal": 2,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "4d9ba531-84fc-4350-be0b-3d0dec7a0297",
#         "attributes": {
#             "duration": 46,
#             "ordinal": 1,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "b53f343d-928b-4e21-9a8a-d88a8afb8c7a",
#         "attributes": {
#             "actor": "1422481252",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 109,
#                 "attachment": 452211619,
#                 "damageDone": 610,
#                 "damageReceived": 931,
#                 "deaths": 3,
#                 "disablesDone": 159,
#                 "disablesReceived": 241,
#                 "emote": 168041925,
#                 "energyGained": 349,
#                 "energyUsed": 150,
#                 "healingDone": 40,
#                 "healingReceived": 39,
#                 "kills": 0,
#                 "mount": 2089656107,
#                 "outfit": 1805653074,
#                 "score": 809,
#                 "side": 2,
#                 "timeAlive": 148
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "815094029707522048"
#                 }
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "3a7f94bd-2cad-43f2-9c7b-bd11af971813",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 3,
#                 "divisionRating": 27,
#                 "league": 2,
#                 "losses": 40,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 3,
#                 "prevDivisionRating": 27,
#                 "prevLeague": 2,
#                 "prevLosses": 39,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 37,
#                 "rankingChangeType": "AllyPlacement",
#                 "roundsLost": 3,
#                 "roundsWon": 1,
#                 "score": 1,
#                 "season": 7,
#                 "teamSize": 1,
#                 "wins": 37
#             },
#             "won": "false"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "b108fd2a-15ae-42d9-ae2b-86460637f9a2"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "d837690f-7fcf-42f4-8e17-1070fa3e9ad8"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "971372861484883968"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "783238845914296320",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/783238845914296320"
#         }
#     },
#     {
#         "type": "team",
#         "id": "974455674039865344",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "2e6f4645-da97-42a3-b331-0760a0fb87d0",
#         "attributes": {
#             "duration": 69,
#             "ordinal": 0,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "928390119004717056",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/928390119004717056"
#         }
#     },
#     {
#         "type": "roster",
#         "id": "79f650b8-dbb7-4117-a155-0584dc63b340",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 2,
#                 "divisionRating": 87,
#                 "league": 2,
#                 "losses": 3,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 2,
#                 "prevDivisionRating": 59,
#                 "prevLeague": 2,
#                 "prevLosses": 3,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 3,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 1,
#                 "roundsWon": 3,
#                 "score": 3,
#                 "season": 7,
#                 "teamSize": 2,
#                 "wins": 4
#             },
#             "won": "true"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "1e69b337-7c33-4b59-b700-e908ae0a4f28"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "9ffcf901-6dc2-480f-a47d-fb9543792387"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "980214695195713536"
#                 }
#             }
#         }
#     },
#     {
#         "type": "asset",
#         "id": "a7e175a3-3541-11e8-9d5c-0a5864604204",
#         "attributes": {
#             "URL": "https://cdn.gamelockerapp.com/stunlock-studios-battlerite/global/2018/04/01/00/14/a7e175a3-3541-11e8-9d5c-0a5864604204-telemetry.json",
#             "createdAt": "2018-04-01T00:14:34Z",
#             "description": "",
#             "name": "telemetry"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "cbd4d3a7-46ea-40bb-9251-5135183ee3e2",
#         "attributes": {
#             "actor": "65687534",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 350,
#                 "attachment": 729140288,
#                 "damageDone": 1806,
#                 "damageReceived": 648,
#                 "deaths": 1,
#                 "disablesDone": 286,
#                 "disablesReceived": 89,
#                 "emote": 1505065066,
#                 "energyGained": 894,
#                 "energyUsed": 125,
#                 "healingDone": 0,
#                 "healingReceived": 174,
#                 "kills": 5,
#                 "mount": 828373934,
#                 "outfit": 1351472700,
#                 "score": 2092,
#                 "side": 1,
#                 "timeAlive": 330
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "974109931747868672"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "779814866243452928",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/779814866243452928"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "7e1806d1-0c34-4c00-8660-2d4e8a418a65",
#         "attributes": {
#             "actor": "1455985392",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 185,
#                 "attachment": 66707064,
#                 "damageDone": 958,
#                 "damageReceived": 907,
#                 "deaths": 0,
#                 "disablesDone": 164,
#                 "disablesReceived": 109,
#                 "emote": 386479715,
#                 "energyGained": 652,
#                 "energyUsed": 400,
#                 "healingDone": 586,
#                 "healingReceived": 471,
#                 "kills": 2,
#                 "mount": 1603856734,
#                 "outfit": 705391268,
#                 "score": 1708,
#                 "side": 2,
#                 "timeAlive": 203
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "886262752514027520"
#                 }
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "23860328-1109-40ce-bf28-3059ce9dd552",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 3,
#                 "divisionRating": 99,
#                 "league": 2,
#                 "losses": 9,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 3,
#                 "prevDivisionRating": 68,
#                 "prevLeague": 2,
#                 "prevLosses": 9,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 20,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 0,
#                 "roundsWon": 3,
#                 "score": 3,
#                 "season": 7,
#                 "teamSize": 2,
#                 "wins": 21
#             },
#             "won": "true"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "7e1806d1-0c34-4c00-8660-2d4e8a418a65"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "81a14cd3-55e4-42c1-85de-025b0c971f86"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "974455674039865344"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "622d00ba-2ac8-49d4-99dc-bcd084784d16",
#         "attributes": {
#             "duration": 133,
#             "ordinal": 3,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "2b77165c-5f53-4bd3-98d6-6f4888ef8966",
#         "attributes": {
#             "actor": "1661996559",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 191,
#                 "attachment": 823239161,
#                 "damageDone": 1331,
#                 "damageReceived": 1393,
#                 "deaths": 3,
#                 "disablesDone": 257,
#                 "disablesReceived": 284,
#                 "emote": 147449486,
#                 "energyGained": 478,
#                 "energyUsed": 300,
#                 "healingDone": 245,
#                 "healingReceived": 591,
#                 "kills": 1,
#                 "mount": 68356694,
#                 "outfit": 675039590,
#                 "score": 1833,
#                 "side": 2,
#                 "timeAlive": 238
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "928390119004717056"
#                 }
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "4b490036-c870-4293-8e6f-06eb60c5ca30",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 5,
#                 "divisionRating": 39,
#                 "league": 2,
#                 "losses": 6,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 5,
#                 "prevDivisionRating": 9,
#                 "prevLeague": 2,
#                 "prevLosses": 6,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 4,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 0,
#                 "roundsWon": 3,
#                 "score": 3,
#                 "season": 7,
#                 "teamSize": 1,
#                 "wins": 5
#             },
#             "won": "true"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "9fd63804-77bd-4330-a542-04c3f16e9526"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "453e21ca-bf21-43a1-aff6-7b8e3cd9c573"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "980197325114847232"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "0d2d2457-9507-4e75-abe0-c53f25f01063",
#         "attributes": {
#             "actor": "1463164578",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 170,
#                 "attachment": 2137091615,
#                 "damageDone": 1145,
#                 "damageReceived": 1421,
#                 "deaths": 2,
#                 "disablesDone": 355,
#                 "disablesReceived": 212,
#                 "emote": 1110814816,
#                 "energyGained": 611,
#                 "energyUsed": 350,
#                 "healingDone": 366,
#                 "healingReceived": 492,
#                 "kills": 1,
#                 "mount": 68356694,
#                 "outfit": 407828710,
#                 "score": 1866,
#                 "side": 1,
#                 "timeAlive": 297
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "972674854530727936"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "86263f36-f936-4aa8-a492-a05d9b666d70",
#         "attributes": {
#             "actor": "1",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 148,
#                 "attachment": 554478717,
#                 "damageDone": 1406,
#                 "damageReceived": 1105,
#                 "deaths": 4,
#                 "disablesDone": 106,
#                 "disablesReceived": 266,
#                 "emote": 1439650029,
#                 "energyGained": 622,
#                 "energyUsed": 400,
#                 "healingDone": 0,
#                 "healingReceived": 216,
#                 "kills": 2,
#                 "mount": 872225242,
#                 "outfit": 887331768,
#                 "score": 1512,
#                 "side": 2,
#                 "timeAlive": 296
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "959658808366534656"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "815094029707522048",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/815094029707522048"
#         }
#     },
#     {
#         "type": "player",
#         "id": "979036743577776128",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/979036743577776128"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "d7fd5373-63f7-4903-9964-adb440b31bd3",
#         "attributes": {
#             "actor": "543520739",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 328,
#                 "attachment": 408773361,
#                 "damageDone": 1612,
#                 "damageReceived": 1711,
#                 "deaths": 1,
#                 "disablesDone": 225,
#                 "disablesReceived": 198,
#                 "emote": 1860433920,
#                 "energyGained": 1152,
#                 "energyUsed": 50,
#                 "healingDone": 1218,
#                 "healingReceived": 1102,
#                 "kills": 3,
#                 "mount": 1720346655,
#                 "outfit": 847148324,
#                 "score": 3055,
#                 "side": 2,
#                 "timeAlive": 325
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "979036743577776128"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "1e69b337-7c33-4b59-b700-e908ae0a4f28",
#         "attributes": {
#             "actor": "65687534",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 455,
#                 "attachment": 130398019,
#                 "damageDone": 1500,
#                 "damageReceived": 1051,
#                 "deaths": 1,
#                 "disablesDone": 280,
#                 "disablesReceived": 273,
#                 "emote": 1505065066,
#                 "energyGained": 1008,
#                 "energyUsed": 700,
#                 "healingDone": 349,
#                 "healingReceived": 314,
#                 "kills": 4,
#                 "mount": 1844725846,
#                 "outfit": 1351472700,
#                 "score": 2129,
#                 "side": 1,
#                 "timeAlive": 247
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "954087761349058560"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "979488397649420288",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/979488397649420288"
#         }
#     },
#     {
#         "type": "player",
#         "id": "980189762944122880",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/980189762944122880"
#         }
#     },
#     {
#         "type": "team",
#         "id": "980228813038432256",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "778932451320934400",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/778932451320934400"
#         }
#     },
#     {
#         "type": "round",
#         "id": "848d7701-8456-4aac-8666-7b273b3d7170",
#         "attributes": {
#             "duration": 52,
#             "ordinal": 2,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "978796308359950336",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "d95d1bdc-0a02-47be-ab23-b3a460bc4947",
#         "attributes": {
#             "duration": 75,
#             "ordinal": 1,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "asset",
#         "id": "626990a2-3541-11e8-b891-0a586460a616",
#         "attributes": {
#             "URL": "https://cdn.gamelockerapp.com/stunlock-studios-battlerite/global/2018/04/01/00/12/626990a2-3541-11e8-b891-0a586460a616-telemetry.json",
#             "createdAt": "2018-04-01T00:12:37Z",
#             "description": "",
#             "name": "telemetry"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "b108fd2a-15ae-42d9-ae2b-86460637f9a2",
#         "attributes": {
#             "actor": "1496688063",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 221,
#                 "attachment": 915074743,
#                 "damageDone": 1712,
#                 "damageReceived": 1410,
#                 "deaths": 3,
#                 "disablesDone": 189,
#                 "disablesReceived": 194,
#                 "emote": 72511009,
#                 "energyGained": 852,
#                 "energyUsed": 500,
#                 "healingDone": 706,
#                 "healingReceived": 541,
#                 "kills": 2,
#                 "mount": 132750854,
#                 "outfit": 610332939,
#                 "score": 2609,
#                 "side": 1,
#                 "timeAlive": 315
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "961260605304659968"
#                 }
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "979085440181223424",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "975201776414416896",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/975201776414416896"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "9ffcf901-6dc2-480f-a47d-fb9543792387",
#         "attributes": {
#             "actor": "1318732017",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 240,
#                 "attachment": 1096863488,
#                 "damageDone": 1424,
#                 "damageReceived": 1137,
#                 "deaths": 1,
#                 "disablesDone": 303,
#                 "disablesReceived": 269,
#                 "emote": 1866269483,
#                 "energyGained": 739,
#                 "energyUsed": 225,
#                 "healingDone": 223,
#                 "healingReceived": 212,
#                 "kills": 2,
#                 "mount": 872225242,
#                 "outfit": 695537120,
#                 "score": 1953,
#                 "side": 1,
#                 "timeAlive": 258
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "937809125767835648"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "781876678661132288",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/781876678661132288"
#         }
#     },
#     {
#         "type": "round",
#         "id": "8bff3265-27a1-43d5-b052-1abd46487f60",
#         "attributes": {
#             "duration": 69,
#             "ordinal": 1,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "3c76440e-7d18-4d5a-bbed-b0b533ce2fd9",
#         "attributes": {
#             "duration": 80,
#             "ordinal": 2,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "980197325114847232",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "979487539570294784",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/979487539570294784"
#         }
#     },
#     {
#         "type": "player",
#         "id": "10066",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/10066"
#         }
#     },
#     {
#         "type": "round",
#         "id": "2a5c6113-30d9-4c9b-b34a-5e753ef9aaf1",
#         "attributes": {
#             "duration": 61,
#             "ordinal": 1,
#             "stats": {
#                 "winningTeam": 2
#             }
#         }
#     },
#     {
#         "type": "asset",
#         "id": "472e3e10-3541-11e8-8b98-0a586460352c",
#         "attributes": {
#             "URL": "https://cdn.gamelockerapp.com/stunlock-studios-battlerite/global/2018/04/01/00/11/472e3e10-3541-11e8-8b98-0a586460352c-telemetry.json",
#             "createdAt": "2018-04-01T00:11:51Z",
#             "description": "",
#             "name": "telemetry"
#         }
#     },
#     {
#         "type": "player",
#         "id": "959658808366534656",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/959658808366534656"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "2421d03e-4f41-4f15-a743-19badcf4fac3",
#         "attributes": {
#             "actor": "65687534",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 363,
#                 "attachment": 578166028,
#                 "damageDone": 1079,
#                 "damageReceived": 1152,
#                 "deaths": 3,
#                 "disablesDone": 77,
#                 "disablesReceived": 256,
#                 "emote": 1505065066,
#                 "energyGained": 608,
#                 "energyUsed": 0,
#                 "healingDone": 0,
#                 "healingReceived": 252,
#                 "kills": 1,
#                 "mount": 1302058678,
#                 "outfit": 1000638222,
#                 "score": 1156,
#                 "side": 2,
#                 "timeAlive": 282
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "979487539570294784"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "9fd63804-77bd-4330-a542-04c3f16e9526",
#         "attributes": {
#             "actor": "39373466",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 189,
#                 "attachment": 520549809,
#                 "damageDone": 1338,
#                 "damageReceived": 654,
#                 "deaths": 0,
#                 "disablesDone": 137,
#                 "disablesReceived": 86,
#                 "emote": 553323459,
#                 "energyGained": 907,
#                 "energyUsed": 625,
#                 "healingDone": 96,
#                 "healingReceived": 352,
#                 "kills": 4,
#                 "mount": 132750854,
#                 "outfit": 1471164257,
#                 "score": 1571,
#                 "side": 1,
#                 "timeAlive": 189
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "783238845914296320"
#                 }
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "16e57781-b113-450e-997a-b69d01e745cb",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": -1,
#                 "divisionRating": -1,
#                 "league": -1,
#                 "losses": 1,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 7,
#                 "prevDivision": -1,
#                 "prevDivisionRating": -1,
#                 "prevLeague": -1,
#                 "prevLosses": 0,
#                 "prevPlacementGamesLeft": 8,
#                 "prevWins": 2,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 3,
#                 "roundsWon": 0,
#                 "score": 0,
#                 "season": 7,
#                 "teamSize": 2,
#                 "wins": 2
#             },
#             "won": "false"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "6c7665d4-b033-4245-bd4a-c7fdec5c8569"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "28df89c5-6f80-4ea0-8ec9-95d92dc941bb"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "980228813038432256"
#                 }
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "35f7597e-6182-49dd-b7bd-5ba0fe47d850",
#         "attributes": {
#             "actor": "39373466",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 189,
#                 "attachment": 520549809,
#                 "damageDone": 1786,
#                 "damageReceived": 892,
#                 "deaths": 2,
#                 "disablesDone": 144,
#                 "disablesReceived": 73,
#                 "emote": 210417291,
#                 "energyGained": 812,
#                 "energyUsed": 475,
#                 "healingDone": 108,
#                 "healingReceived": 375,
#                 "kills": 3,
#                 "mount": 68356694,
#                 "outfit": 1732432398,
#                 "score": 2038,
#                 "side": 2,
#                 "timeAlive": 238
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "975201776414416896"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "c0a66311-ae9e-4d3e-a528-edf51bfeb588",
#         "attributes": {
#             "duration": 72,
#             "ordinal": 1,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "954087761349058560",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/954087761349058560"
#         }
#     },
#     {
#         "type": "team",
#         "id": "974113568553316352",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "44c0fb72-70d0-46aa-bff5-5fa1bc4ac0c4",
#         "attributes": {
#             "duration": 109,
#             "ordinal": 2,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "28df89c5-6f80-4ea0-8ec9-95d92dc941bb",
#         "attributes": {
#             "actor": "65687534",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 380,
#                 "attachment": 578166028,
#                 "damageDone": 720,
#                 "damageReceived": 717,
#                 "deaths": 3,
#                 "disablesDone": 47,
#                 "disablesReceived": 123,
#                 "emote": 1505065066,
#                 "energyGained": 624,
#                 "energyUsed": 75,
#                 "healingDone": 0,
#                 "healingReceived": 54,
#                 "kills": 0,
#                 "mount": 1302058678,
#                 "outfit": 893016916,
#                 "score": 767,
#                 "side": 1,
#                 "timeAlive": 190
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "980226622844243968"
#                 }
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "886262752514027520",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/886262752514027520"
#         }
#     },
#     {
#         "type": "roster",
#         "id": "eec4bab3-1575-4ed6-a893-69af55a4c22d",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 3,
#                 "divisionRating": 48,
#                 "league": 2,
#                 "losses": 10,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 3,
#                 "prevDivisionRating": 24,
#                 "prevLeague": 2,
#                 "prevLosses": 10,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 10,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 1,
#                 "roundsWon": 3,
#                 "score": 3,
#                 "season": 7,
#                 "teamSize": 1,
#                 "wins": 11
#             },
#             "won": "true"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "35f7597e-6182-49dd-b7bd-5ba0fe47d850"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "d7fd5373-63f7-4903-9964-adb440b31bd3"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "979085440181223424"
#                 }
#             }
#         }
#     },
#     {
#         "type": "roster",
#         "id": "ef1ce93e-fa06-4444-b104-7f16da9d5ede",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 4,
#                 "divisionRating": 97,
#                 "league": 1,
#                 "losses": 37,
#                 "matchRegion": "south_america",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 4,
#                 "prevDivisionRating": 73,
#                 "prevLeague": 1,
#                 "prevLosses": 37,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 39,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 1,
#                 "roundsWon": 3,
#                 "score": 3,
#                 "season": 7,
#                 "teamSize": 3,
#                 "wins": 40
#             },
#             "won": "true"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "cbd4d3a7-46ea-40bb-9251-5135183ee3e2"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "1528a283-2bf9-44d1-b5b0-a5801129c70f"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "0d2d2457-9507-4e75-abe0-c53f25f01063"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "974113568553316352"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "12fc083f-b82c-4eac-952b-dfbcbcd4814c",
#         "attributes": {
#             "duration": 66,
#             "ordinal": 2,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "961748057458876416",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/961748057458876416"
#         }
#     },
#     {
#         "type": "participant",
#         "id": "d837690f-7fcf-42f4-8e17-1070fa3e9ad8",
#         "attributes": {
#             "actor": "154382530",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 107,
#                 "attachment": 1898490815,
#                 "damageDone": 1564,
#                 "damageReceived": 1394,
#                 "deaths": 3,
#                 "disablesDone": 82,
#                 "disablesReceived": 175,
#                 "emote": 1062218161,
#                 "energyGained": 492,
#                 "energyUsed": 225,
#                 "healingDone": 132,
#                 "healingReceived": 413,
#                 "kills": 1,
#                 "mount": 1583480623,
#                 "outfit": 426441717,
#                 "score": 1778,
#                 "side": 1,
#                 "timeAlive": 214
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "778932451320934400"
#                 }
#             }
#         }
#     },
#     {
#         "type": "team",
#         "id": "980214695195713536",
#         "attributes": {
#             "name": "",
#             "shardId": "global",
#             "stats": null,
#             "titleId": "stunlock-studios-battlerite"
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         }
#     },
#     {
#         "type": "participant",
#         "id": "5bac1947-46c9-4636-96b1-d90f9b2b912e",
#         "attributes": {
#             "actor": "44962063",
#             "shardId": "global",
#             "stats": {
#                 "abilityUses": 193,
#                 "attachment": 795452698,
#                 "damageDone": 1068,
#                 "damageReceived": 1263,
#                 "deaths": 3,
#                 "disablesDone": 285,
#                 "disablesReceived": 299,
#                 "emote": 1610770225,
#                 "energyGained": 572,
#                 "energyUsed": 225,
#                 "healingDone": 734,
#                 "healingReceived": 620,
#                 "kills": 1,
#                 "mount": 1058172411,
#                 "outfit": 764425193,
#                 "score": 2087,
#                 "side": 2,
#                 "timeAlive": 241
#             }
#         },
#         "relationships": {
#             "player": {
#                 "data": {
#                     "type": "player",
#                     "id": "781876678661132288"
#                 }
#             }
#         }
#     },
#     {
#         "type": "round",
#         "id": "480d7327-a5ff-4f5c-b6a9-c86acb8ae80b",
#         "attributes": {
#             "duration": 81,
#             "ordinal": 3,
#             "stats": {
#                 "winningTeam": 1
#             }
#         }
#     },
#     {
#         "type": "player",
#         "id": "973762206573436928",
#         "attributes": {
#             "name": "",
#             "patchVersion": "",
#             "shardId": "",
#             "stats": null,
#             "titleId": ""
#         },
#         "relationships": {
#             "assets": {
#                 "data": []
#             }
#         },
#         "links": {
#             "schema": "",
#             "self": "https://api.dc01.gamelockerapp.com/shards//players/973762206573436928"
#         }
#     },
#     {
#         "type": "roster",
#         "id": "4420bdd1-8b99-4ae9-a81d-a2fec01ff9d0",
#         "attributes": {
#             "shardId": "global",
#             "stats": {
#                 "division": 3,
#                 "divisionRating": 4,
#                 "league": 2,
#                 "losses": 181,
#                 "matchRegion": "eu",
#                 "placementGamesLeft": 0,
#                 "prevDivision": 3,
#                 "prevDivisionRating": 33,
#                 "prevLeague": 2,
#                 "prevLosses": 180,
#                 "prevPlacementGamesLeft": 0,
#                 "prevWins": 155,
#                 "rankingChangeType": "Default",
#                 "roundsLost": 3,
#                 "roundsWon": 0,
#                 "score": 0,
#                 "season": 7,
#                 "teamSize": 1,
#                 "wins": 155
#             },
#             "won": "false"
#         },
#         "relationships": {
#             "participants": {
#                 "data": [
#                     {
#                         "type": "participant",
#                         "id": "b53f343d-928b-4e21-9a8a-d88a8afb8c7a"
#                     },
#                     {
#                         "type": "participant",
#                         "id": "3ea3dc5c-db05-4183-93ab-3cdb7ef9a59f"
#                     }
#                 ]
#             },
#             "team": {
#                 "data": {
#                     "type": "team",
#                     "id": "972483100003147776"
#                 }
#             }
#         }
#     }
# ]

# %% [markdown]
# > The 'included' key holds various pieces of information, but the only thing I am interested in are the telemetry urls holding the telemetry data of each match.

# %% [markdown]
# <a id='data2'></a>
# ### Collect data
# #### Description:
# > Now that I understand the structure of the data, I can start collecting my data.
#
# #### Procedure:
# > I will first create two functions, one to extract the necessary data receieved and store it as a DataFrame, and another to get a chunk of data for a specified date. Once these functions have been created, I will collect data from various days and hours for the months of January 2018 to April 2018. Because of the current date (April 10), I will only collect data for the first week of April.
# 1. Build a function to extract data
# 2. Build a function to get data for specified date
# 3. Collect data

# %% [markdown]
# ##### 1. Build a function to extract data

# %%
def extract(data):
    '''
    Get match data, and store in a DataFrame
    '''
    
    # Get telemetry urls
    telemetry_urls = {}
    for entry in data['included']:
        if entry['type'] == 'asset':
            telemetry_urls[str(entry['id'])] = entry['attributes']['URL']

    # Get match data
    match_data = {'date':[], 'match_id':[], 'game_mode':[], 'ranked':[], 'character':[], 'league':[], 'win':[]}
    for entry in data['data']:
        if entry['attributes']['stats']['type'] in ['QUICK2V2', 'QUICK3V3', 'LEAGUE2V2', 'LEAGUE3V3']:
            # Get date
            date = datetime.strptime(entry['attributes']['createdAt'], '%Y-%m-%dT%H:%M:%SZ')
            match_data['date'] = date
            
            # Get match id
            match_id = entry['id']

            # Get game mode (2v2 or 3v3)
            game_mode = entry['attributes']['stats']['type'][-3:]

            # Get telemetry data
            asset_id = entry['relationships']['assets']['data'][0]['id']
            url = telemetry_urls[asset_id]
            r = requests.get(url, headers={"Accept":"application/vnd.api+json"})
            telemetry = r.json()

            # Get player info
            players = []
            for entry in telemetry:
                # Determine winning team
                if entry['type'] == 'Structures.MatchFinishedEvent':
                    if entry['dataObject']['teamOneScore'] > entry['dataObject']['teamTwoScore']:
                        winner = 1
                    else:
                        winner = 2
                
                # Gather player info
                if entry['type'] == 'Structures.MatchReservedUser':
                    players.append(entry)

            for player in players:
                # Gather player info
                character = player['dataObject']['character']
                league = player['dataObject']['league']
                if player['dataObject']['team'] == winner:
                    win = True
                else:
                    win = False

                # Store player info
                match_data['character'].append(character)
                match_data['league'].append(league)
                match_data['win'].append(win)
            
            # Determine if the game was ranked
            if players[0]['dataObject']['rankingType'] == 'RANKED':
                ranked = True
            else:
                ranked = False

            count = len(players)
            # Store remaining data
            match_data['match_id'] += [match_id]*count
            match_data['game_mode'] += [game_mode]*count
            match_data['ranked'] += [ranked]*count
            
    # Convert into DataFrame
    DataFrame = pd.DataFrame(match_data)
    
    return DataFrame

# %% [markdown]
# ##### 2. Build a function to get data for specified date

# %%
def get_chunk(df=pd.DataFrame(), year=2018, month=1, day=1, hour=0, minute=0):
    '''
    Get chunk of data
    '''
    
    # Initialize start and end dates
    start = datetime(year, month, day, hour, minute, 0, 0)
    end = start + timedelta(days=1)
    
    # Get data from first page
    url = "https://api.dc01.gamelockerapp.com/shards/global/matches"
    data = get_data(url, start, end)
    temp = extract(data)
    df = pd.concat([df, temp], ignore_index=True)
    
    # Get data from next pages
    for i in range(9):
        # Get the next page
        url = data['links']['next']
        data = get_data(url)
        
        # Create DataFrame
        temp = extract(data)

        # Concatenate DataFrames
        df = pd.concat([df, temp], ignore_index=True)
        
    # Delay requests
    time.sleep(53)
    
    return df

# %% [markdown]
# ##### 3. Collect Data

# %%
'''First Run'''
# Initialize empty DataFrame
match_df = pd.DataFrame()

# Cycle through Jan-March
for month in range(1,4):
    # Cycle through various days of the month
    for day in range(1,29,3):
        # Update DataFrame
        match_df = get_chunk(match_df, 2018, month, day)

# Cycle through first week of April
for day in range(1,8):
    # Update DataFrame
    match_df = get_chunk(match_df, 2018, 4, day)

# Save DataFrame
#match_df.to_csv('compiled_data\match_data', index=False)

# %%
'''Second Run'''
# Initialize empty DataFrame
match_df = pd.DataFrame()

# Cycle through Jan-March
for month in range(1,4):
    # Cycle through various days of the month
    for day in range(1,29,3):
        # Cycle through various hours of the day
        for hour in [0, 18, 19, 20, 21, 22, 23]:
            # Cycle through various minutes of the day
            for minute in range(0,60,10):
                # Update DataFrame
                match_df = get_chunk(match_df, 2018, month, day, hour, minute)

# Cycle through first week of April
for day in range(1,8):
    # Cycle through various hours of the day
    for hour in [0, 18, 19, 20, 21, 22, 23]:
        # Cycle through various minutes of the day
            for minute in range(0,60,10):
                # Update DataFrame
                match_df = get_chunk(match_df, 2018, 4, day, hour, minute)

# Save DataFrame
#match_df.to_csv('compiled_data\match_data2', index=False)

# %% [markdown]
# <a id='characters'></a>
# <div class="alert alert-block alert-warning">
# <h1 align="center">Character Mappings</h3>
# </div>

# %% [markdown]
# <a id='character1'></a>
# ### Build character mappings
# #### Description:
# > Now that I have collected my data, I must map each character to its corresponding name. To do this, I will have to go through the "gameplay.json", and "English.ini" files and link the corresponding data.
#
# > The "gameplay.json" file includes information on each character.
# <br> For each character, there are two IDs, a "typeID" and a "name". </br>
# <br> The "typeID" corresponds to the ID stored in my collected data, while the "name" is an ID in the "English.ini" file that can be used to find each character's name. </br>
#
# #### Procedure:
# > I will first go through the "gameplay.json" file to create a DataFrame to store each character's "typeID" and "name" ID, then go through the "English.ini" file to create a separate DataFrame to store the mappings of each "name" ID and its value. I can then merge these two DataFrames using an inner join to map each "typeID" with the correct name.
# 1. Build DataFrame using "gameplay.json"
# 2. Build DataFrame using "English.ini"
# 3. Build character mappings

# %% [markdown]
# ##### 1. Build DataFrame using "gameplay.json"

# %%
# Open 'gameplay.json' and load as a json file
gameplay_json = open('mappings\gameplay.json', 'r').read()
character_mappings = json.loads(gameplay_json)['characters']

# Loop through each character and store the 'typeID' and 'name' attributes
character_names = defaultdict(list)
for character in character_mappings:
    character_names['characterID'].append(character['typeID'])
    character_names['nameID'].append(character['name'])

# Turn character_names into a DataFrame
character_names = pd.DataFrame(character_names)

# %% [markdown]
# ##### 2. Build DataFrame using "English.ini"

# %%
# Open 'English.ini' file and store
filename = 'mappings\English.ini'
localization_mapping = {}
with open(filename, encoding='utf8') as text:
    for line in text:
        key, value = line.split('=', 1)
        localization_mapping[key] = value[:-1]

# Turn localization_mapping into a DataFrame
localization_mapping = pd.DataFrame.from_dict(localization_mapping, orient='index').reset_index().rename(columns={0:'name'})

# %% [markdown]
# ##### 3. Build character mappings

# %%
# Merge the two DataFrames to match 'characterID' to 'name'
character_names = character_names.merge(localization_mapping, left_on='nameID', right_on='index')
# Drop unnecessary columns
character_names = character_names.drop(columns=['nameID', 'index'])

# Save data
character_names.to_csv('compiled_data\character_names', index=False)
character_names.head()
# Out:
#    characterID      name
# 0    467463015     Lucie
# 1    259914044    Sirius
# 2   1649551456  Pestilus
# 3    543520739   Blossom
# 4    842211418       Iva
